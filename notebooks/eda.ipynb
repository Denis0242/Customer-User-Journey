# %% [markdown]
# # Customer User Journey EDA
# Portfolio notebook for funnel, retention, churn risk, and revenue analysis.

# %%
import pandas as pd
df = pd.read_csv('../data/customer_user_journey.csv')
df.head()

# %%
df.groupby('Funnel Stage')['Customer ID'].nunique()
